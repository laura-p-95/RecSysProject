# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/My Drive/Recommender_Sys
# Out:
# /gdrive/My Drive/Recommender_Sys

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
URM_training = pd.read_csv("/gdrive/My Drive/Recommender_Sys/recommender-system-2021-challenge-polimi/data_train.csv", 
                                sep=",", 
                                header=None, 
                                skiprows = [0],
                                engine='python')

URM_training.columns = ["UserID", "ItemID", "Interaction"]
#Items are the TVShows!

# %%
URM_training.head(n=20)
# Out:
#     UserID  ItemID  Interaction
# 0        0      53          1.0
# 1        0     209          1.0
# 2        0     223          1.0
# 3        0     249          1.0
# 4        0     435          1.0
# 5        0     460          1.0
# 6        0     652          1.0
# 7        0     960          1.0
# 8        0     973          1.0
# 9        0    1103          1.0
# 10       0    1215          1.0
# 11       0    1267          1.0
# 12       0    1418          1.0
# 13       0    1455          1.0
# 14       0    1461          1.0
# 15       0    1496          1.0
# 16       0    1782          1.0
# 17       0    1964          1.0
# 18       0    2083          1.0
# 19       0    2307          1.0

# %%
URM_popular = pd.read_csv("/gdrive/My Drive/Recommender_Sys/recommender-system-2021-challenge-polimi/orderedItems.csv", 
                                sep=",", 
                                names=["ItemIDs", "InteractionSum"], 
                                skiprows = [0],
                                usecols=[0,1],
                                engine='python')

#Items are the TVShows!

# %%
URM_popular.head(n=20)
# Out:
#     ItemIDs  InteractionSum
# 0      6177         11199.0
# 1      3899         10118.0
# 2      3473         10109.0
# 3      6214          9541.0
# 4      8635          9378.0
# 5     17330          8914.0
# 6     16365          8520.0
# 7     15119          8505.0
# 8      5273          8477.0
# 9     14181          8289.0
# 10    14358          8287.0
# 11    16846          8287.0
# 12    10865          8237.0
# 13     2665          8173.0
# 14    13134          8066.0
# 15    15778          7929.0
# 16     5925          7810.0
# 17    13914          7502.0
# 18    13229          7462.0
# 19     6975          7424.0

# %%
userID_unique = URM_training["UserID"].unique()
itemID_unique = URM_training["ItemID"].unique()

# %%
n_users = len(userID_unique)
n_items = len(itemID_unique)
n_interactions = len(URM_training)

print ("Number of items\t {}".format(n_items))
print ("Max ID items\t {}".format(max(itemID_unique)))
print("")
print ("Number of users\t {}".format(n_users))
print ("Max Id users\t {}".format(max(userID_unique)))
print("")
print ("Number of interactions\t {}".format(n_interactions))
# Out:
# Number of items	 18059
# Max ID items	 18058
#
# Number of users	 13650
# Max Id users	 13649
#
# Number of interactions	 5285664

# %%
print ("Sparsity {:.2f} %".format((1-float(n_interactions)/(n_items*n_users))*100))
# Out:
# Sparsity 97.86 %

# %%
import scipy.sparse as sps
import matplotlib.pyplot as pyplot

# %%
URM_training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5285664 entries, 0 to 5285663
# Data columns (total 3 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   UserID       int64
#  1   ItemID       int64
#  2   Interaction  float64
# dtypes: float64(1), int64(2)
# memory usage: 121.0 MB

# %%
URM_training.shape
# Out:
# (5285664, 3)

# %%
URM_popular.shape
# Out:
# (18059, 2)

# %%
import numpy as np
from Recommenders.BaseRecommender import BaseRecommender
from Recommenders.Recommender_utils import check_matrix
from Recommenders.DataIO import DataIO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-2227b3e1326f> in <module>()
#       1 import numpy as np
# ----> 2 from Recommenders.BaseRecommender import BaseRecommender
#       3 from Recommenders.Recommender_utils import check_matrix
#       4 from Recommenders.DataIO import DataIO
#
# ModuleNotFoundError: No module named 'Recommenders'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
classTop
